# %%
# Vamos extrair as medidas do diagrama e organizá-las em uma tabela baseada na posição em que aparecem.
import pandas as pd

# Criando uma lista de medidas e suas posições baseadas no diagrama visual
medidas = [
    {'Posição': 'OAL ref', 'Medida': 293.5, 'Unidade': 'mm'},
    {'Posição': '1.8 stock', 'Medida': 43, 'Unidade': 'mm'},
    {'Posição': 'pivot pin C to back of receiver', 'Medida': 236, 'Unidade': 'mm'},
    {'Posição': '28.2 (largura superior esquerda)', 'Medida': 28.2, 'Unidade': 'mm'},
    {'Posição': '38 (largura superior esquerda)', 'Medida': 38, 'Unidade': 'mm'},
    {'Posição': '65 (distância central)', 'Medida': 65, 'Unidade': 'mm'},
    {'Posição': '104 (distância entre seções centrais)', 'Medida': 104, 'Unidade': 'mm'},
    {'Posição': '109 (comprimento inferior direito)', 'Medida': 109, 'Unidade': 'mm'},
    {'Posição': '14.1 (raio do pino de pivô)', 'Medida': 14.1, 'Unidade': 'mm'},
    {'Posição': '14.5R (raio superior esquerdo)', 'Medida': 14.5, 'Unidade': 'mm'},
    {'Posição': '8.5 (diâmetro superior direito)', 'Medida': 8.5, 'Unidade': 'mm'},
    {'Posição': '15 (diâmetro superior direito)', 'Medida': 15, 'Unidade': 'mm'},
    {'Posição': '46 (distância da extremidade direita)', 'Medida': 46, 'Unidade': 'mm'},
    {'Posição': '21 (largura inferior direita)', 'Medida': 21, 'Unidade': 'mm'},
    {'Posição': '9 (diâmetro de furo)', 'Medida': 9, 'Unidade': 'mm'},
    {'Posição': '3.1 (diâmetro do furo central)', 'Medida': 3.1, 'Unidade': 'mm'},
    {'Posição': '45 (ângulo de inclinação)', 'Medida': 45, 'Unidade': 'graus'},
    {'Posição': '7° (ângulo)', 'Medida': 7, 'Unidade': 'graus'},
    {'Posição': '30° (ângulo)', 'Medida': 30, 'Unidade': 'graus'},
]

# Criar DataFrame
df_medidas = pd.DataFrame(medidas)

# Aplicar a escala de 1:1, multiplicando as medidas por 1.43 (aproximadamente 1/0.7)
df_medidas['Medida (escala 1:1)'] = df_medidas['Medida'] * 1.43
df_medidas[['Posição', 'Medida (escala 1:1)', 'Unidade']]

df_medidas
# Out:
#                                   Posição  Medida Unidade  Medida (escala 1:1)
# 0                                 OAL ref   293.5      mm              419.705
# 1                               1.8 stock    43.0      mm               61.490
# 2         pivot pin C to back of receiver   236.0      mm              337.480
# 3        28.2 (largura superior esquerda)    28.2      mm               40.326
# 4          38 (largura superior esquerda)    38.0      mm               54.340
# 5                  65 (distância central)    65.0      mm               92.950
# 6   104 (distância entre seções centrais)   104.0      mm              148.720
# 7      109 (comprimento inferior direito)   109.0      mm              155.870
# 8             14.1 (raio do pino de pivô)    14.1      mm               20.163
# 9          14.5R (raio superior esquerdo)    14.5      mm               20.735
# 10        8.5 (diâmetro superior direito)     8.5      mm               12.155
# ...
